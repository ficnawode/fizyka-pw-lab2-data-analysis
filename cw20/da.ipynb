# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
filenames = [
    'photoblue',
    'photodark',
    'photored',
    'schottky',
    'silicon',
    'tunnel',
    'zener',
]

# %%
#load data into a dictionary
dsets = {}
for name in filenames:
    filepath = 'in_refactored/' + name + '.txt'
    dsets[name] = pd.read_csv(filepath, sep='\t')

# %%
plt.figure(figsize=(8,6))
_linewidth=1
plt.plot(dsets['photoblue']['U'], dsets['photoblue']['I'], label='niebieski', color='blue', linewidth=_linewidth)
plt.plot(dsets['photored']['U'], dsets['photored']['I'], label='czerwony', color='red', linewidth=_linewidth)
plt.plot(dsets['photodark']['U'], dsets['photodark']['I'], label='brak', color='grey', linewidth=_linewidth)

plt.xlabel(r'$U \; [V]$')
plt.ylabel(r'$I \; [A]$')

plt.legend()

plt.savefig('out/wyk_I_od_U_color.jpg', dpi=350)
plt.show()

# %%
plt.figure(figsize=(8,6))

plt.plot(dsets['photoblue']['U'], dsets['photoblue']['I'], label='niebieski', color='blue', linewidth=_linewidth)
plt.plot(dsets['photored']['U'], dsets['photored']['I'], label='czerwony', color='red', linewidth=_linewidth)
plt.plot(dsets['photodark']['U'], dsets['photodark']['I'], label='brak', color='grey', linewidth=_linewidth)

plt.xlabel(r'$U \; [V]$')
plt.ylabel(r'$I \; [A]$')

plt.xlim([-0.4,0.7])
plt.ylim([-0.001,0.004])

plt.legend()

plt.savefig('out/wyk_I_od_U_color_zoom.jpg', dpi=350)
plt.show()

# %%
plt.figure(figsize=(8,6))

plt.plot(dsets['schottky']['U'], dsets['schottky']['I'], color='green', linewidth=_linewidth)

plt.xlabel(r'$U \; [V]$')
plt.ylabel(r'$I \; [A]$')

plt.savefig('out/wyk_I_od_U_schottky.jpg', dpi=350)
plt.show()

# %%
plt.figure(figsize=(8,6))

plt.plot(dsets['silicon']['U'], dsets['silicon']['I'], color='orange', linewidth=_linewidth)

plt.xlabel(r'$U \; [V]$')
plt.ylabel(r'$I \; [A]$')

plt.savefig('out/wyk_I_od_U_silicon.jpg', dpi=350)
plt.show()

# %%
plt.figure(figsize=(8,6))

plt.plot(dsets['tunnel']['U'], dsets['tunnel']['I'], color='magenta', linewidth=_linewidth)

plt.xlabel(r'$U \; [V]$')
plt.ylabel(r'$I \; [A]$')

plt.savefig('out/wyk_I_od_U_tunnel.jpg', dpi=350)
plt.show()

# %%
plt.figure(figsize=(8,6))

plt.plot(dsets['zener']['U'], dsets['zener']['I'], color='purple', linewidth=_linewidth)

plt.xlabel(r'$U \; [V]$')
plt.ylabel(r'$I \; [A]$')

plt.savefig('out/wyk_I_od_U_zener.jpg', dpi=350)
plt.show()
